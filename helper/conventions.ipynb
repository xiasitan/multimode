# %% [markdown]
# ### Coherent State displacment axis
# real displacements are along the y axis and imaginary along the x axis.

# %%
using Plots
using QuantumOptics

include("C:/Users/jonat/Desktop/Code/multimode/helper/visualization.jl")
bc = FockBasis(16)
state = coherentstate(bc, 1.0im)
x = [-5:0.01:5;]
quick_plot_wigner(state, x, x, size = (500,500))
